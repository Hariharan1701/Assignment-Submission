# %%
import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Assignment 1

# %%
x = np.arange(0,10)
y = 3*x + 10

## plt plot
plt.plot(x,y,'ro--')

# %%
plt.plot(x,y,'r*',linestyle='dashed',linewidth=2,markersize=12)
plt.xlabel('X-axis',color='blue')
plt.xlabel('X-axis',color='blue')
plt.title('2d-Diagram', color='blue')
# Out:
# Text(0.5, 1.0, '2d-Diagram')

# %% [markdown]
# # Assignment 2

# %%
x = [1,2,3,4,5,6,7] #days of the weeks
y = [160,150,140,145,175,165,180] #sales

plt.plot(x,y)
plt.show()

# %%
days =[1,2,3,4,5,6,7] # days of the week
sales_1 = [160,150,140,145,175,165,180] #sales of company1
sales_2 = [70,90,160,150,140,145,175] #sales of company2

plt.figure(figsize = (6,5) ,dpi=150)
plt.plot(days,sales_1)
plt.plot(days,sales_2)
plt.title("Sales per day in USD",fontsize = 10 , color='red') #title
plt.xlabel('Days of the week')
plt.ylabel('Sales')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
